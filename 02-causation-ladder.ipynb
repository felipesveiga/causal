# %% [markdown]
# <h1 style='font-size:40px'>
#     The Ladder of Causation
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
#  </div>

# %% [markdown]
# <h2 style='font-size:30px'> Introduction
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa seção, estudamos cada um dos degraus da Causalidade estabelecidos por Judea Pearl.
#         </li>
#         <li>
#             Cada degrau representa um grau de análise em nosso estudo.
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Explicar degraus de causalidade de Judea Pearl'
! git push
# Out:
# [master 3bd797d] Quiz 1
#  3 files changed, 78 insertions(+), 12 deletions(-)
#  create mode 100644 img/01-causal-workflow.png
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 76.49 KiB | 38.25 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/felipesveiga/causal.git
#    0dccc99..3bd797d  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei Aula 9; Explicar degraus de causalidade de Judea Pearl
