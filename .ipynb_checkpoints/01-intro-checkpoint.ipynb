# %% [markdown]
# <h1 style='font-size:40px'>
#     Causality, Association & RCT's
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A Inferência Causal é um ramo da Estatística voltado à identificação da causa de um determinado fenômeno.
#         </li>
#         <li>
#             Diferentemente da correlação, que identifica se a alteração de uma variável está associada à mudança de em outra, a Inferência Causal propõe uma análise mais profunda, tentando descobrir se a mudança de um dado <strong> causa</strong>, necessariamente, a mudança de outro.
#         </li>
#     </ul>
#  </div>

# %% [markdown]
# <h2 style='font-size:30px'> Simpson's Paradox
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O Paradoxo de Simpson é um dos fenômenos que fundamentam a área da Inferência Causal.
#         </li>
#         <li>
#             Ele aponta que, em comparações qualitativas, uma alternativa possa ter estatísticas melhores do que a outra em visões apartadas, mas, no agregado, ter o menor desempenho.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Exemplo</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A imagem abaixo mostra os resultados de um estudo sobre danificação de mercadorias usando diferentes embalagens e rotas de entrega.
#         </li>
#         <li>
#             Note que, apesar de a rota B ter o menor nível de dano para ambas as embalagens, ela ainda tem uma porcentagem maior do que a A no agregado.
#         </li>
#         <li>
#             Isso ocorreu porque a maior parte da amostragem de A foi feita com embalagens reforçadas. Já a de B teve 90% de suas entregas com a embalagem padrão.
#         </li>
#         <li>
#             Assim, como a taxa de dano em A com embalagens reforçadas foi menor do que em B com as padrões, o seu percentual agregado conseguiu ficar menor!
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#             <img src='img/01-simpson.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h2 style='font-size:30px'> The Need for Causality in Business
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A ascensão da Ciência de Dados no mercado muito se deveu ao desejo das empresas de conseguirem <i> automatizar</i> tomadas de decisão com base em análises estatísticas de seus dados.
#         </li>
#         <li>
#             Diante desse cenário, os <i>modelos preditivos</i> (regressão linear, SVM, Random Forest) se destacaram em satisfazer esse desejo. Dado um conjunto de features $x$, prevemos a variável $y$ desejada.
#         </li>
#         <li>
#             Por outro lado, muitos negócios também enxergam um grande potencial <i> experimental</i> na análise de seus dados. Poderíamos usá-los para inferir consequências de tomadas de decisão ou intervenções à empresa.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Predictive x Causal</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             É pensando nessa necessidade que são desenvolvidos modelos causais. Diferentemente dos preditivos, esses algoritmos são usados para <i> simular</i> como uma target $y$ responderia a intervenções em nossas features.
#         </li>
#         <li>
#             Seu uso é adequado quando a realização prática dessas intervenções pode gerar um risco ao negócio ou se mostrar antiética.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> Causation and its relation to Association
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, delineamos conceitos fundamentais da Inferência Causal.
#         </li>
#         <li>
#             Como já dissemos, a Inferência Causal é área de foco experimental, em que tentamos inferir o impacto de diferentes ações numa variável $y$.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Fundamental Problem of Causal Inference</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             De forma ideal, se quiséssemos estimar o efeito causal de uma ação, deveríamos comparar o efeito de fazê-la com o de não fazê-la.
#         </li>
#         <li>
#             O grande problema disso é que muitas vezes é impossível fazer essa mensuração, porque teremos que escolher apenas uma das ações possíveis.
#         </li>
#         <li>
#             Essa questão compõe o que denominamos como o <i> Problema Fundamental da Inferência Causal.</i>
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $E[Y(T=1)]-E[Y(T=0)]$
#             <figcaption style='font-size:15px'>
#                 Definição ideal de causalidade da aplicação de um tratamento.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Terminologias Causais</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A fim de tornar mais compreensível os conceitos por trás da Inferência Causal, precisamos definir alguns jargões usados corriqueiramente no campo.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Unit</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Consiste em uma instância de nossa amostra sujeita aos tratamentos sob análise.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Potential Outcome</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Potencial Outcomes consistem em todos os resultados possíveis de ocorrerem em nosso experimento, para cada tratamento $t$ aplicado em nosso ambiente.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $y=\{y_{1},y_{2},\ldots,y_{n}\}$
#             <figcaption style='font-size:15px'>
#                 Listagem de todos os potential outcomes possíveis de um experimento.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Factual Outcome</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Consiste no resultado real obtido ao escolhermos aplicar um dos tratamentos $t$ possíveis a uma unit.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Counterfactual</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Um contrafactual seria o resultado de termos escolhido um outro tratamento à instância.
#         </li>
#         <li>
#             Naturalmente, ele jamais poderá ser observado no mundo real, dado que escolhemos um outro tratamento.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Individual Treatment Effect</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Definimos como Individual Treatment Effect a diferença do efeito para quando aplicamos ou não a intervenção analisada numa determinada unit.
#         </li>
#         <li>
#             Mas observe, como não conseguimos observar contrafactuais, nunca poderemos mensurar com exatidão um ITE.
#         </li>
#         <li>
#             Nesse caso, deveremos recorrer aos dados das units que receberam o tratamento contrário da nossa instância para conseguir estimar o possível ITE. Quanto mais similares as units forem, mais confiável será nossa mensuração.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\tau_{i}=Y_{i}(1)-Y_{i}(0)$
#             <figcaption style='font-size:15px'>
#                 Definição formal de ITE.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Average Treatment Effect</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O Average Treatment Effect seria uma métrica voltada à análise do tratamento numa amostra de units.
#         </li>
#         <li>
#             Nesse caso, avaliaríamos o impacto médio de nossa intervenção medindo o ITE médio obtido em nossa amostra.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\tau=E[Y(1)-Y(0)]=E[Y(1)]-E[Y(0)]$
#             <figcaption style='font-size:15px'>
#                 Definição formal de ATE.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Assim como em ITE's, nós não conseguimos mensurar com exatidão o ATE por conta dos contrafactuais.
#         </li>
#         <li>
#             Nesse caso, poderíamos tentar aproximar $\tau$ à diferença entre o efeito médio observado nas instâncias com o tratamento e o tido entre as que não receberam.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\tau\approx{E[Y|T=1]-E[Y|T=0]}$
#             <figcaption style='font-size:15px'>
#                 Aproximação de $\tau$ com o uso dos dados amostrais.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Causation & Association - The Causal Inference Purpose</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Quando estudamos a associação entre duas variáveis, podemos constatar que essas apresentaram uma relação <i>causal</i> em certas instâncias, ou <i>espúria</i> (não-causal) em outras.
#         </li>
#         <li>
#             Por exemplo, por mais que o consumo de sorvete aumente em dias ensolarados, não podemos dizer que 100% dele provém desse motivo (algumas pessoas podem gostar de tomá-lo, independentemente do tempo). Nessa situação, a associação entre as variáveis ocorre tanto de forma causal, quanto espúria.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\text{Association}=\text{Causation}+\text{Bias}$
#             <figcaption style='font-size:15px'>
#                 Consideramos que a associação de duas variáveis pode ser decomposta entre o que é causal e apenas viés (espúrio).
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Considerando a relação acima, a Inferência Causal supõe que, caso eliminemos todo o viés presente em nossa amostra, poderemos considerar que a diferença de efeito observada é igual ao ATE!
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\tau={E[Y|T=1]-E[Y|T=0]}\iff{\text{Bias}=0}$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h2 style='font-size:30px'> SUTVA
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A fim de garantir a precisão das medições, os experimentos causais devem seguir uma série de preceitos, conhecida como Stable Unit Treatment Value Asssumption (SUTVA).
#             <ul>
#                 <li>
#                     O resultado de uma unit não deve ser influenciado pelo tratamento de uma outra.
#                 </li>
#                 <li>
#                      A ordem causal deve ser pré- estabelecida, de modo que $T_{i}$ cause $Y_{i}$, mas não o contrário!
#                 </li>
#                 <li>
#                     Tratamentos de mesma categoria devem ser aplicados de forma igual a todos os participantes. Por exemplo, ao avaliarmos o impacto de uma medicação, talvez seja interessante considerar sua versão injetável e em cápsulas diferentes tratamentos.
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> Métricas de Causalidade
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Vamos mencionar abaixo um compilado de métricas de causalidade que podem ser usadas em projetos.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Variáveis Contínuas</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Em experimentos que envolvem targets contínuas, normalmente se analise o quociente entre os potential outcomes, ou o aumento percentual devido ao tratamento.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\tau_{i}=\frac{Y_{i}(1)}{Y_{i}(0)}$ | $\tau_{i}=\frac{Y_{i}(1)-Y_{i}(0)}{Y_{i}(0)}$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Variáveis Binárias</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Análises que envolvem targets binárias trabalham com a diferença entre os potential outcomes (UTE).
#         </li>
#         <li>
#             Nessa situação, existem diversas métricas que possibilitam olhares com diferentes granularidades sobre nosso experimento.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Sample Average Treatment Effect (SATE) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#              Consiste na média dos UTE's da nossa amostra.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{SATE}=\frac{1}{n}{\sum_{i=1}^{n}[Y_{i}(1)-Y_{i}(0)]}$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Population Average Treatment Effect (PATE) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#               Seria o tamanho do efeito de tratamento estimado na população sob análise.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{PATE}=E[Y_{i}(1)-Y_{i}(0)]$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Sample Average Treatment Effect for the Treated (SATT) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#              Consiste na média dos UTE's de apenas os participantes que receberam o tratamento sob análise.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{SATT}=\frac{1}{\sum_{i=1}^{n}T_{i}}{\sum_{i=1}^{n}T_{i}[Y_{i}(1)-Y_{i}(0)]}$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Population Average Treatment Effect for the Treated (PATT) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Seria a estimativa do efeito do tratamento na parcela da população de ação.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{PATT}=E[Y_{i}(1)-Y_{i}(0)|T_{i}=1]$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Conditional Average Treatment Effect (CATE) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O CATE consiste na avaliação do efeito do tratamento em grupos de características em comum dentro de nossa amostragem.
#         </li>
#         <li>
#             Caso o CATE se diferencie pelos grupos da amostragem, podemos dizer que $X_{i}$ modera o efeito de tratamento.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{CATE}=E[Y_{i}(1)-Y_{i}(0)|X_{i}=1]$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> $\alpha$-Quantile Treatment Effect (QTE$_{\alpha}$) </h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O QTE$_{\alpha}$ busca avaliar um percentil dos efeitos de tratamento observados em nossa amostra.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             $\displaystyle \operatorname{QTE}_{\alpha}=q_{1}(\alpha)-q_{0}(\alpha)$
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %%
# Stable Unit Treatment Value Assumption

# %%
! git add .
! git commit -am 'Continuar artigo de "1.4 Causal Effects of Immutable Characteristics"'
! git push
# Out:
# [master 7b6b652] Definir QTE
#  2 files changed, 192 insertions(+), 12 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.14 KiB | 1.14 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/felipesveiga/causal.git
#    eb6ad9b..7b6b652  master -> master

# %% [markdown]
# <p style='color:red'> Defini QTE; Continuar artigo de "1.4 Causal Effects of Immutable Characteristics"
