# %% [markdown]
# <h1 style='font-size:40px'>
#     Causal Inference Part 2: Estimation
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa seção, iremos aprender as principais técnicas de estimação de efeito em nossos experimentos.
#         </li>
#     </ul>
#  </div>

# %%
! git add .
! git commit -am 'Aula 35'
! git push
# Out:
# [master 899c87c] Quiz 5
#  2 files changed, 58 insertions(+), 14 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 915 bytes | 915.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/causal.git
#    381e90b..899c87c  master -> master

# %% [markdown]
# <p style='color:red'> Fiz Quiz 5; Iniciei seção 5; Aula 35
