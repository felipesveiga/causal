# %% [markdown]
# <h1 style='font-size:40px'>
#     Causl Directed Acyclic Graphs
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
#  </div>

# %%
! git add .
! git commit -am 'Iniciar seção 3'
! git push
# Out:
# [master 9a1308c] Iniciar seção 3
#  2 files changed, 58 insertions(+), 22 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 843 bytes | 843.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/causal.git
#    e93ec9c..9a1308c  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aula 16; Fiz Quiz 2; Iniciar seção 3
