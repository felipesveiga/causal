# %% [markdown]
# <h1 style='font-size:40px'>
#     Causal Inference Part 1: Identification
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Em Causalidade, o processo de Identificação seria a análise de se conseguimos extrair uma quantia causal a partir dos nossos dados observacionais.
#         </li>
#     </ul>
#  </div>

# %%
! git add .
! git commit -am 'Aula 27 (6:10)'
! git push
# Out:
# [master 3d36ec7] Fazer Quiz 3
#  2 files changed, 88 insertions(+), 14 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 961 bytes | 961.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/causal.git
#    d79f160..3d36ec7  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei seção 4; A Aula 27 começa definindo o conceito de Ignorabilidade; Aula 27 (6:10)
