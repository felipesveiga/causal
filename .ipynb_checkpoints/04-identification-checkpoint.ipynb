# %% [markdown]
# <h1 style='font-size:40px'>
#     Causal Inference Part 1: Identification
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Em Causalidade, o processo de Identificação seria a análise de se conseguimos extrair uma quantia causal a partir dos nossos dados observacionais.
#         </li>
#     </ul>
#  </div>

# %%
! git add .
! git commit -am 'Fazer anotações Aula 27, mencionando o uso de Conditional Ignorability na computação do ATE'
! git push
# Out:
# [master 181373a] Aula 27 (6:10)
#  4 files changed, 172 insertions(+), 88 deletions(-)
#  create mode 100644 .ipynb_checkpoints/04-identification-checkpoint.ipynb
#  create mode 100644 04-identification.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 917 bytes | 917.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/felipesveiga/causal.git
#    3d36ec7..181373a  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aula 27; Fazer anotações Aula 27, mencionando o uso de Conditional Ignorability na computação do ATE
